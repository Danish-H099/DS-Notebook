# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Read Json to CSV

# %%
Data = '{"employee_name": "James", "email": "james@gmail.com", "job_profile": [{"title1":"Team Lead", "title2":"Sr. Developer"}]}'
df=pd.read_json(Data)
df.head()
# Out:
#   employee_name            email  \
# 0         James  james@gmail.com
#
#                                          job_profile
# 0  {'title1': 'Team Lead', 'title2': 'Sr. Develop...

# %% [markdown]
# Converting json to different json format

# %%
df.to_json(orient="index")
# Out:
# '{"0":{"employee_name":"James","email":"james@gmail.com","job_profile":{"title1":"Team Lead","title2":"Sr. Developer"}}}'

# %%
df.to_json(orient="records")
# Out:
# '[{"employee_name":"James","email":"james@gmail.com","job_profile":{"title1":"Team Lead","title2":"Sr. Developer"}}]'

# %% [markdown]
# ## Reading HTML content (Web Scraping)

# %% [markdown]
# we get the data from table of a web page and this is called WEB SCRAPING

# %%
url = 'https://en.wikipedia.org/wiki/International_cricket'

df1 = pd.read_html(url)

# %% [markdown]
# df1 is the list of table

# %%
df1
# Out:
# [           Team             ICC Men's Cricket World Cup  \
#  0     Australia  6 (1987, 1999, 2003, 2007, 2015, 2023)
#  1   West Indies                          2 (1975, 1979)
#  2         India                          2 (1983, 2011)
#  3       England                                1 (2019)
#  4      Pakistan                                1 (1992)
#  5     Sri Lanka                                1 (1996)
#  6   New Zealand                                       0
#  7  South Africa                                       0
#  8  Total played                                      13
#
#    ICC Men's T20 World Cup ICC World Test Championship Final  \
#  0                1 (2021)                          1 (2023)
#  1          2 (2012, 2016)                                 0
#  2                1 (2007)                                 0
#  3          2 (2010, 2022)                                 0
#  4                1 (2009)                                 0
# ...

# %%
df1[0]
# Out:
#            Team             ICC Men's Cricket World Cup  \
# 0     Australia  6 (1987, 1999, 2003, 2007, 2015, 2023)
# 1   West Indies                          2 (1975, 1979)
# 2         India                          2 (1983, 2011)
# 3       England                                1 (2019)
# 4      Pakistan                                1 (1992)
# 5     Sri Lanka                                1 (1996)
# 6   New Zealand                                       0
# 7  South Africa                                       0
# 8  Total played                                      13
#
#   ICC Men's T20 World Cup ICC World Test Championship Final  \
# 0                1 (2021)                          1 (2023)
# 1          2 (2012, 2016)                                 0
# 2                1 (2007)                                 0
# 3          2 (2010, 2022)                                 0
# 4                1 (2009)                                 0
# ...

# %% [markdown]
# # Pickling
# All pandas objects are equipped with to_pickle methods which use Python’s cPickle module to save data structures to disk using the pickle format.

# %%
df=pd.read_pickle('df_excel')

# %%
df.head()
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15
